# %%
from nltk.parse import CoreNLPParser
from nltk.corpus.reader.conll import ConllCorpusReader
from nltk.tag.perceptron import PerceptronTagger
from nltk.grammar import DependencyGrammar
from nltk.parse import (
     DependencyGraph,
     ProjectiveDependencyParser,
     NonprojectiveDependencyParser,
 )
from nltk import FreqDist
from pprint import pprint
import math

parser = CoreNLPParser(url='http://localhost:9000')

root = "."
train = "fr-ud-train.conllu3"
test = "fr-ud-test.conllu3"
COLUMN_TYPES = ('ignore', 
                'words', 
                'ignore', 
                'pos', 
                'ignore', 
                'ignore', 
                'ignore', 
                'ignore', 
                'ignore', 
                'ignore')

trainCorpus  = ConllCorpusReader(root=root, 
                                  fileids=train, 
                                  columntypes=COLUMN_TYPES, 
                                  encoding='utf8', 
                                  separator="\t", 
                                  tagset='universal')

testCorpus  = ConllCorpusReader(root=root, 
                                  fileids=test, 
                                  columntypes=COLUMN_TYPES, 
                                
                                  encoding='utf8', 
                                  separator="\t", 
                                  tagset='universal')

testWords = testCorpus.sents()

myfile = open("./fr-ud-test.conllu3")
conllfile = myfile.read()

# séparation du fichier conll en lignes
ff = conllfile.split('\n\n')

dg = []
sents = []

for sent in testWords:
    wlist = []
    for word in sent:
        wlist.append(word + ' ')
    sents.append(''.join(wlist))

nps = []

for sent in sents[:1]:
    tree = next(parser.raw_parse(sent))
    for st in tree.subtrees(filter = lambda x: x.label() == "NP"):
        print(st)
        nps.append(st)

fdist = FreqDist(nps)
fdist.most_common(10)
# Out:
# (NP
#   (PRON Je)
#   (VERB sens)
#   (PP
#     (SCONJ qu')
#     (NP
#       (VERB entre)
#       (PRON ça)
#       (PP
#         (CONJ et)
#         (NP
#           (DET les)
#           (NOUN films)
#           (PP
#             (ADP de)
#             (NP
#               (NOUN médecins)
#               (CONJ et)
#               (PP (NOUN scientifiques) (NP (NOUN fous) (SCONJ que))))))))))
# (NP
#   (VERB entre)
#   (PRON ça)
#   (PP
#     (CONJ et)
#     (NP
#       (DET les)
#       (NOUN films)
#       (PP
#         (ADP de)
#         (NP
#           (NOUN médecins)
#           (CONJ et)
#           (PP (NOUN scientifiques) (NP (NOUN fous) (SCONJ que))))))))
# (NP
#   (DET les)
#   (NOUN films)
#   (PP
#     (ADP de)
#     (NP
#       (NOUN médecins)
#       (CONJ et)
#       (PP (NOUN scientifiques) (NP (NOUN fous) (SCONJ que))))))
# (NP
#   (NOUN médecins)
#   (CONJ et)
#   (PP (NOUN scientifiques) (NP (NOUN fous) (SCONJ que))))
# (NP (NOUN fous) (SCONJ que))
# (NP
#   (PRON nous)
#   (AUX pourrions)
#   (PP
#     (VERB emprunter)
#     (NP
#       (DET un)
#       (ADJ autre)
#       (NOUN chemin)
#       (PP (ADP pour) (NP (DET l') (NOUN origine))))))
# (NP
#   (DET un)
#   (ADJ autre)
#   (NOUN chemin)
#   (PP (ADP pour) (NP (DET l') (NOUN origine))))
# (NP (DET l') (NOUN origine))
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-210-15de8a6dcf0b> in <module>
#      68         nps.append(st)
#      69
# ---> 70 fdist = FreqDist(nps)
#      71 fdist.most_common(10)
#      72
#
# /usr/local/lib/python3.5/dist-packages/nltk/probability.py in __init__(self, samples)
#     106         :type samples: Sequence
#     107         """
# --> 108         Counter.__init__(self, samples)
#     109
#     110         # Cached number of samples in this FreqDist
#
# /usr/lib/python3.5/collections/__init__.py in __init__(*args, **kwds)
#     528             raise TypeError('expected at most 1 arguments, got %d' % len(args))
#     529         super(Counter, self).__init__()
# --> 530         self.update(*args, **kwds)
#     531
#     532     def __missing__(self, key):
#
# /usr/local/lib/python3.5/dist-packages/nltk/probability.py in update(self, *args, **kwargs)
#     144         """
#     145         self._N = None
# --> 146         super(FreqDist, self).update(*args, **kwargs)
#     147
#     148     def setdefault(self, key, val):
#
# /usr/lib/python3.5/collections/__init__.py in update(*args, **kwds)
#     615                     super(Counter, self).update(iterable) # fast path when counter is empty
#     616             else:
# --> 617                 _count_elements(self, iterable)
#     618         if kwds:
#     619             self.update(kwds)
#
# TypeError: unhashable type: 'Tree'
